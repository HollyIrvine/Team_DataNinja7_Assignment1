# %% [markdown]
# <a href="https://colab.research.google.com/github/HollyIrvine/Team_DataNinja7_Assignment1/blob/Team_DataNinja7_Assignment1/Individual_Analyses/TeamMember4_Regional_Operations_Analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Operations_analysts

# 1.2 State-Level Performance (Top 10 by Sales)
# This query details sales, profit, and profit margin for each state,
# ordered by total sales to identify top-performing states.

# %%bigquery --project supple-design-465411-c1
SELECT
    state, -- Changed from "State" to "state"
    SUM(sales) AS Total_Sales,
    SUM(profit) AS Total_Profit,
    (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) AS Profit_Margin_Percent,
    COUNT(DISTINCT order_id) AS Total_Orders
FROM
    `supple-design-465411-c1`.Lab1_Eda3.Super_Store2019_2022
GROUP BY
    state
ORDER BY
    Total_Sales DESC
LIMIT 10; -- Adjust LIMIT as needed for more/ fewer states
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           state  Total_Sales  Total_Profit  Profit_Margin_Percent  \
# 0    California  457687.6315    76381.3871              16.688541
# 1      New York  310876.2710    74038.5486              23.816082
# 2         Texas  170188.0458   -25729.3563             -15.118192
# 3    Washington  138641.2700    33402.6517              24.092863
# 4  Pennsylvania  116511.9140   -15559.9603             -13.354823
# 5       Florida   89473.7080    -3399.3017              -3.799219
# 6      Illinois   80166.1010   -12607.8870             -15.727205
# 7          Ohio   78258.1360   -16971.3766             -21.686405
# 8      Michigan   76269.6140    24463.1876              32.074618
# 9      Virginia   70636.7200    18597.9504              26.329012
#
#    Total_Orders
# 0          1021
# 1           562
# 2           487
# 3           256
# 4           288
# 5           200
# 6           276
# 7           236
# 8           117
# 9           115

# %%
# Operations_analysts

#1.3 State-Level Performance (Bottom 10 by Profit Margin)
#This query identifies states with the lowest profit margins,
#which might indicate areas for consolidation or operational review.

# %%bigquery --project supple-design-465411-c1
SELECT
    state,
    SUM(sales) AS Total_Sales,
    SUM(profit) AS Total_Profit,
    (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) AS Profit_Margin_Percent,
    COUNT(DISTINCT order_id) AS Total_Orders
FROM
    `supple-design-465411-c1`.Lab1_Eda3.Super_Store2019_2022
GROUP BY
    state
HAVING
    SUM(sales) > 0 -- Exclude states with no sales to avoid division by zero issues
ORDER BY
    Profit_Margin_Percent ASC
LIMIT 10; -- Adjust LIMIT as needed
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             state  Total_Sales  Total_Profit  Profit_Margin_Percent  \
# 0            Ohio   78258.1360   -16971.3766             -21.686405
# 1        Colorado   32108.1180    -6527.8579             -20.330864
# 2       Tennessee   30661.8730    -5341.6936             -17.421289
# 3        Illinois   80166.1010   -12607.8870             -15.727205
# 4           Texas  170188.0458   -25729.3563             -15.118192
# 5  North Carolina   55603.1640    -7490.9122             -13.472097
# 6    Pennsylvania  116511.9140   -15559.9603             -13.354823
# 7         Arizona   35282.0010    -3427.9246              -9.715789
# 8          Oregon   17431.1500    -1190.4705              -6.829558
# 9         Florida   89473.7080    -3399.3017              -3.799219
#
#    Total_Orders
# 0           236
# 1            79
# 2            91
# 3           276
# 4           487
# 5           136
# 6           288
# 7           108
# 8            56
# 9           200

# %%
# Operations_analysts

#2.3 Performance by Product Category and Sub-Category
#This helps identify which product lines are contributing most to sales and profit,
#or which might be underperforming.


# %%bigquery --project supple-design-465411-c1

SELECT
    category, -- Changed from "Category" to "category"
    subcategory, -- Changed from "Sub-Category" to "subcategory"
    SUM(sales) AS Total_Sales,
    SUM(profit) AS Total_Profit,
    (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) AS Profit_Margin_Percent,
    COUNT(DISTINCT order_id) AS Total_Orders
FROM
    `supple-design-465411-c1`.Lab1_Eda3.Super_Store2019_2022
GROUP BY
    category,
    subcategory
ORDER BY
    Total_Profit DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#            category  subcategory  Total_Sales  Total_Profit  \
# 0        Technology      Copiers  149528.0300    55617.8249
# 1        Technology       Phones  330007.0540    44515.7306
# 2        Technology  Accessories  167380.3180    41936.6357
# 3   Office Supplies        Paper   78479.2060    34053.5693
# 4   Office Supplies      Binders  203412.7330    30221.7633
# 5         Furniture       Chairs  328449.1030    26590.1663
# 6   Office Supplies      Storage  223843.6080    21278.8264
# 7   Office Supplies   Appliances  107532.1610    18138.0054
# 8         Furniture  Furnishings   91705.1640    13059.1436
# 9   Office Supplies    Envelopes   16476.4020     6964.1767
# 10  Office Supplies          Art   27118.7920     6527.7870
# 11  Office Supplies       Labels   12486.3120     5546.2540
# 12       Technology     Machines  189238.6310     3384.7569
# 13  Office Supplies    Fasteners    3024.2800      949.5182
# 14  Office Supplies     Supplies   46673.5380    -1189.0995
# 15        Furniture    Bookcases  114879.9963    -3472.5560
# 16        Furniture       Tables  206965.5320   -17725.4811
#
#     Profit_Margin_Percent  Total_Orders
# 0               37.195585            68
# 1               13.489327           814
# 2               25.054700           718
# 3               43.391837          1191
# 4               14.857361          1316
# 5                8.095673           576
# 6                9.506113           777
# 7               16.867517           451
# 8               14.240358           877
# 9               42.267582           249
# 10              24.071083           731
# 11              44.418672           346
# 12               1.788618           112
# 13              31.396504           215
# 14              -2.547695           187
# 15              -3.022768           224
# 16              -8.564460           307

# %%
# Operations_analysts

#FOCUS QUESTION 3: Where should we expand or consolidate?
#Required Analysis: Market opportunity identification


#3.1 States with High Sales but Low Profit (Potential for Consolidation/Efficiency Improvement)
#suggesting issues with costs, discounts, or operational inefficiencies.


# %%bigquery --project supple-design-465411-c1

SELECT
    state,
    SUM(sales) AS Total_Sales,
    SUM(profit) AS Total_Profit,
    (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) AS Profit_Margin_Percent
FROM
    `supple-design-465411-c1`.Lab1_Eda3.Super_Store2019_2022
GROUP BY
    state
HAVING
    SUM(sales) > 10000 -- Set a reasonable sales threshold to focus on significant markets
    AND (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) < 5 -- Example: Profit margin less than 5%
ORDER BY
    Profit_Margin_Percent ASC, Total_Sales DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             state  Total_Sales  Total_Profit  Profit_Margin_Percent
# 0            Ohio   78258.1360   -16971.3766             -21.686405
# 1        Colorado   32108.1180    -6527.8579             -20.330864
# 2       Tennessee   30661.8730    -5341.6936             -17.421289
# 3        Illinois   80166.1010   -12607.8870             -15.727205
# 4           Texas  170188.0458   -25729.3563             -15.118192
# 5  North Carolina   55603.1640    -7490.9122             -13.472097
# 6    Pennsylvania  116511.9140   -15559.9603             -13.354823
# 7         Arizona   35282.0010    -3427.9246              -9.715789
# 8          Oregon   17431.1500    -1190.4705              -6.829558
# 9         Florida   89473.7080    -3399.3017              -3.799219

# %%
# Operations_analysts

#3.2 States with High Profit and Good Sales (Potential for Expansion)
#These are the "star" areas where the business is performing well.
#Expansion efforts could yield good returns here.

# %%bigquery --project supple-design-465411-c1

SELECT
    state,
    SUM(sales) AS Total_Sales,
    SUM(profit) AS Total_Profit,
    (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) AS Profit_Margin_Percent
FROM
    `supple-design-465411-c1`.Lab1_Eda3.Super_Store2019_2022
GROUP BY
    state
HAVING
    SUM(sales) > 50000 -- Set a reasonable sales threshold for significant markets
    AND (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) > 15 -- Example: Profit margin greater than 15%
ORDER BY
    Profit_Margin_Percent DESC, Total_Sales DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         state  Total_Sales  Total_Profit  Profit_Margin_Percent
# 0     Indiana   53555.3600    18382.9363              34.325110
# 1    Michigan   76269.6140    24463.1876              32.074618
# 2    Virginia   70636.7200    18597.9504              26.329012
# 3  Washington  138641.2700    33402.6517              24.092863
# 4    New York  310876.2710    74038.5486              23.816082
# 5  California  457687.6315    76381.3871              16.688541

# %%
#3.3 Identify Underperforming Product Categories/Sub-Categories in Specific Regions
#This query helps pinpoint specific product lines that are struggling in certain regions,
#indicating where consolidation or strategic changes might be needed.

# %%bigquery --project supple-design-465411-c1


SELECT
    region,
    category,
    subcategory,
    SUM(sales) AS Total_Sales,
    SUM(profit) AS Total_Profit,
    (SUM(profit) * 100.0 / NULLIF(SUM(sales), 0)) AS Profit_Margin_Percent
FROM
    `supple-design-465411-c1`.Lab1_Eda3.Super_Store2019_2022
GROUP BY
    region,
    category,
    subcategory
HAVING
    SUM(sales) > 1000 -- Consider only categories with meaningful sales
    AND SUM(profit) < 0 -- Focus on categories that are losing money
ORDER BY
    Total_Profit ASC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      region         category  subcategory  Total_Sales  Total_Profit  \
# 0      East        Furniture       Tables   39139.8070   -11025.3801
# 1     South        Furniture       Tables   43916.1920    -4623.0579
# 2   Central        Furniture  Furnishings   15254.3700    -3906.2168
# 3   Central        Furniture       Tables   39154.9710    -3559.6504
# 4   Central  Office Supplies   Appliances   23582.0330    -2638.6175
# 5   Central        Furniture    Bookcases   24157.1768    -1997.9043
# 6      West        Furniture    Bookcases   36004.1235    -1646.5117
# 7   Central       Technology     Machines   26797.3840    -1486.0666
# 8     South       Technology     Machines   53890.9600    -1438.8930
# 9      East        Furniture    Bookcases   43819.3340    -1167.6318
# 10     East  Office Supplies     Supplies   10760.1160    -1155.1352
# 11  Central  Office Supplies      Binders   56923.2820    -1043.6369
# 12  Central  Office Supplies     Supplies    9467.3720     -661.8881
# 13     West       Technology     Machines   42444.1220     -618.9264
#
#     Profit_Margin_Percent
# 0              -28.169224
# 1              -10.527001
# 2              -25.607198
# 3               -9.091184
# 4              -11.189101
# 5               -8.270438
# 6               -4.573120
# 7               -5.545566
# 8               -2.670008
# 9               -2.664650
# 10             -10.735342
# 11              -1.833410
# 12              -6.991255
# 13              -1.458215
